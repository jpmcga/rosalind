# %%
def count_nucleotides(string):
    string = string.lower()
    a = string.count('a')
    t = string.count('t')
    c = string.count('c')
    g = string.count('g')
    
    return a, t, c, g

# %%
A,T,C,G = count_nucleotides('...')
print(f"{A} {C} {G} {T}")
# Out:
# 238 220 232 250
