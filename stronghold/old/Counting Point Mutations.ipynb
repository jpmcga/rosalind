# %%
def get_hamming(string1, string2):

    hamming = 0
    for pos in range(len(string1)):
        if string1[pos] != string2[pos]:
            hamming += 1
    return hamming

# %%
s1 = "..."
s2 = "..."

get_hamming(s1, s2)
# Out:
# 442
